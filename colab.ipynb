# %%
import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader


class SimpleModel(nn.Module):
    # a simple MLP
    def __init__(
        self, n_input: int = 3072000, n_output: int = 3, n_h: int = 128, n_hl: int = 2
    ):
        super().__init__()

        self.n_input = n_input
        self.n_h = n_h
        self.n_hl = n_hl
        self.n_output = n_output

        self.input_layer = nn.Linear(self.n_input, self.n_h)
        self.output_layer = nn.Linear(self.n_h, self.n_output)
        self.hidden_layers = nn.ModuleList()
        for _ in range(self.n_hl - 1):
            self.hidden_layers.append(nn.Linear(self.n_h, self.n_h))

    def forward(self, x):
        h = F.relu(self.input_layer(x))
        for l in self.hidden_layers:
            h = F.relu(l(h))
        out = F.sigmoid(self.output_layer(h))
        return out


def img_processor(img_path):
    # a simple flattening processor
    img = cv2.imread(img_path)
    img = torch.FloatTensor(img).flatten().unsqueeze(0)
    return img


def labeler(filepath):
    id = filepath.split("/")[-1].split("_")[0]
    return id


def gen_labels(names):
    n_samples = len(names)
    n_unique_values = list(set(names))
    n_people = len(n_unique_values)
    n_output = n_people + 1  # add unidentified case
    matched_dict = {"unidentified": -1}
    for k, v in enumerate(n_unique_values):
        matched_dict[v] = k

    labels = torch.zeros((n_samples, n_output))
    for i, n in enumerate(names):
        id = matched_dict[n]
        labels[i, id] = 1
    return labels, matched_dict


def main():
    img_dirs = glob.glob("vein_dataset/train/**/*.jpg", recursive=True)
    data_x = []
    names = []
    for img_path in img_dirs:
        img = img_processor(img_path)
        label = labeler(img_path)

        data_x.append(img)
        names.append(label)
    data_x = torch.cat(data_x, dim=0)
    data_y, matched_dict = gen_labels(names)

    # Hyperparameters
    n_epochs = 100
    n_h = 256
    n_hl = 2
    batch_size = 4
    lr = 1e-3

    # Instance declarations
    model = SimpleModel(n_h=n_h, n_hl=n_hl).to(device)
    dataset = TensorDataset(data_x, data_y)
    dataloader = DataLoader(
        dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True
    )
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Training loops
    for i_epoch in range(n_epochs):
        for i_batch, batch in enumerate(dataloader):
            b_x, b_y = batch
            b_x = b_x.to(device)
            b_y = b_y.to(device)
            b_y_hat = model(b_x)
            loss = F.mse_loss(b_y, b_y_hat)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            print(
                f"Epoch {i_epoch+1} (Batch {i_batch+1}/{len(dataloader)}), Loss={loss.item():.5f}"
            )
            pass
    pass


if __name__ == "__main__":
    device = torch.device("mps")
    main()
# Out:
# /Users/hyeonbeen/miniconda3/envs/ai/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 115
#     113 if __name__ == "__main__":
#     114     device = torch.device("mps")
# --> 115     main()
#
# Cell In[1], line 104, in main()
#     102 optimizer.zero_grad()
#     103 loss.backward()
# --> 104 optimizer.step()
#     106 print(
#     107     f"Epoch {i_epoch+1} (Batch {i_batch+1}/{len(dataloader)}), Loss={loss.item():.5f}"
#     108 )
#     109 pass
#
# File ~/miniconda3/envs/ai/lib/python3.12/site-packages/torch/optim/optimizer.py:485, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     480         else:
#     481             raise RuntimeError(
#     482                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     483             )
# --> 485 out = func(*args, **kwargs)
#     486 self._optimizer_step_code()
#     488 # call optimizer step post hooks
#
# File ~/miniconda3/envs/ai/lib/python3.12/site-packages/torch/optim/optimizer.py:79, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      77     torch.set_grad_enabled(self.defaults["differentiable"])
#      78     torch._dynamo.graph_break()
# ---> 79     ret = func(self, *args, **kwargs)
#      80 finally:
#      81     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/ai/lib/python3.12/site-packages/torch/optim/adam.py:246, in Adam.step(self, closure)
#     234     beta1, beta2 = group["betas"]
#     236     has_complex = self._init_group(
#     237         group,
#     238         params_with_grad,
#    (...)    243         state_steps,
#     244     )
# --> 246     adam(
#     247         params_with_grad,
#     248         grads,
#     249         exp_avgs,
#     250         exp_avg_sqs,
#     251         max_exp_avg_sqs,
#     252         state_steps,
#     253         amsgrad=group["amsgrad"],
#     254         has_complex=has_complex,
#     255         beta1=beta1,
#     256         beta2=beta2,
#     257         lr=group["lr"],
#     258         weight_decay=group["weight_decay"],
#     259         eps=group["eps"],
#     260         maximize=group["maximize"],
#     261         foreach=group["foreach"],
#     262         capturable=group["capturable"],
#     263         differentiable=group["differentiable"],
#     264         fused=group["fused"],
#     265         grad_scale=getattr(self, "grad_scale", None),
#     266         found_inf=getattr(self, "found_inf", None),
#     267         decoupled_weight_decay=group["decoupled_weight_decay"],
#     268     )
#     270 return loss
#
# File ~/miniconda3/envs/ai/lib/python3.12/site-packages/torch/optim/optimizer.py:147, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     145     return disabled_func(*args, **kwargs)
#     146 else:
# --> 147     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/ai/lib/python3.12/site-packages/torch/optim/adam.py:933, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     930 else:
#     931     func = _single_tensor_adam
# --> 933 func(
#     934     params,
#     935     grads,
#     936     exp_avgs,
#     937     exp_avg_sqs,
#     938     max_exp_avg_sqs,
#     939     state_steps,
#     940     amsgrad=amsgrad,
#     941     has_complex=has_complex,
#     942     beta1=beta1,
#     943     beta2=beta2,
#     944     lr=lr,
#     945     weight_decay=weight_decay,
#     946     eps=eps,
#     947     maximize=maximize,
#     948     capturable=capturable,
#     949     differentiable=differentiable,
#     950     grad_scale=grad_scale,
#     951     found_inf=found_inf,
#     952     decoupled_weight_decay=decoupled_weight_decay,
#     953 )
#
# File ~/miniconda3/envs/ai/lib/python3.12/site-packages/torch/optim/adam.py:525, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     523         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     524     else:
# --> 525         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     527     param.addcdiv_(exp_avg, denom, value=-step_size)
#     529 # Lastly, switch back to complex view
#
# RuntimeError: MPS backend out of memory (MPS allocated: 15.66 GB, other allocations: 10.39 MB, max allowed: 18.13 GB). Tried to allocate 2.93 GB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).
